# %% [markdown]
# ## **Image Inpainting -**
# </br>
#
# *random sampling*
#
# *probability - 50%*
# </br>
# </br>
#
# ### Learning type -
#
# *plain_type*
#
# *residual_type*
# </br>
# </br>
#
# ### Network -
#
# *UNet*

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'test'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/inpainting/plain'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/inpainting/plain'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/inpainting/plain'\
--network 'unet'\
--task 'inpainting'\
--num_epoch 50\
--opts 'random' 0.5\
--learning_type 'plain'

# inpainting(plain)

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'train'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/inpainting/residual'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/inpainting/residual'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/inpainting/residual'\
--network 'unet'\
--task 'inpainting'\
--opts 'random' 0.5\
--learning_type 'residual'

# inpainting(residual)

# %% [markdown]
# ## **Image Denoising -**
# </br>
#
# *random noise*
#
# *sigma - 30.0*
# </br>
# </br>
#
# ### Learning type -
#
# *plain_type*
#
# *residual_type*
# </br>
# </br>
#
# ### Network -
#
# *UNet*

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'train'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/denoising/plain'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/denoising/plain'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/denoising/plain'\
--network 'unet'\
--task 'denoising'\
--opts 'random' 0.5\
--learning_type 'plain'

# denoising(plain)

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'train'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/denoising/residual'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/denoising/residual'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/denoising/residual'\
--network 'unet'\
--task 'denoising'\
--opts 'random' 0.5\
--learning_type 'residual'

# denoising(residual)

# %% [markdown]
# ## **Image Super Resolution -**
# </br>
#
# *bilinear interpolation*
#
# *x4 down-sampling*
# </br>
# </br>
#
# ### Learning type -
#
# *plain_type*
#
# *residual_type*
# </br>
# </br>
#
# ### Network -
#
# *UNet*

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'train'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/super_resolution/plain'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/super_resolution/plain'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/super_resolution/plain'\
--network 'unet'\
--task 'super_resolution'\
--opts 'bilinear' 4.0\
--learning_type 'plain'

# Super resolution(plain)

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-image-regression-framework/train.py'\
--mode 'train'\
--data_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/datasets/BSR/BSDS500/data/images'\
--ckpt_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/checkpoint/super_resolution/residual'\
--log_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/log/super_resolution/residual'\
--result_dir '/content/drive/MyDrive/002-pytorch-image-regression-framework/results/super_resolution/residual'\
--network 'unet'\
--task 'super_resolution'\
--opts 'bilinear' 4.0\
--learning_type 'residual'

# Super resolution(residual)
